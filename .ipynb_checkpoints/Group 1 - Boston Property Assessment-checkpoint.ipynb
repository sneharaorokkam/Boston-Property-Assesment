# %% [markdown]
# <p><br>
# <center>
# <b><h1>ALY6140 : Analytics System Technology</h1></b>
# <b><h2>Northeastern University</h2></b>
# <b><h2>Daya Rudhramoorthi </h2></b>
# <b><h2>Group 1 - Bhavik Bhosale, Sneha Rokkam</h2></b>
# <b><h2>Capstone Group Project</h2></b>
# <b><h2>Boston Property Assesment</h2></b>
# </center>
# </p>

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.options.display.float_format = '{:.2f}'.format


import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %% [markdown]
# ## Read the Dataset

# %%
assesment_data = pd.read_csv("PropertyAssesments.csv")
assesment_data.head(5)
# Out:
#          PID  CM_ID     GIS_ID  ST_NUM       ST_NAME UNIT_NUM         CITY  \
# 0  100001000    NaN  100001000  104.00     PUTNAM ST      NaN  EAST BOSTON
# 1  100002000    NaN  100002000  197.00  Lexington ST      NaN  EAST BOSTON
# 2  100003000    NaN  100003000  199.00  Lexington ST      NaN  EAST BOSTON
# 3  100004000    NaN  100004000  201.00  Lexington ST      NaN  EAST BOSTON
# 4  100005000    NaN  100005000  203.00  Lexington ST      NaN  EAST BOSTON
#
#    ZIP_CODE  BLDG_SEQ  NUM_BLDGS  LUC  LU             LU_DESC  \
# 0   2128.00      1.00          1  105  R3  THREE-FAM DWELLING
# 1   2128.00      1.00          1  105  R3  THREE-FAM DWELLING
# 2   2128.00      1.00          1  105  R3  THREE-FAM DWELLING
# 3   2128.00      1.00          1  105  R3  THREE-FAM DWELLING
# 4   2128.00      1.00          1  104  R2    TWO-FAM DWELLING
#
#          BLDG_TYPE OWN_OCC                   OWNER  \
# 0     RE - Row End       Y          PASCUCCI CARLO
# 1  RM - Row Middle       Y       SEMBRANO RODERICK
# 2  RM - Row Middle       N  GUERRA CHEVARRIA ANA S
# 3  RM - Row Middle       N   MADDALENI JAMES E, TS
# 4     RE - Row End       Y     MARKS TRAVIS JOSEPH
#
#                         OWNER MAIL ADDRESS  RES_FLOOR  CD_FLOOR  RES_UNITS  \
# 0  195 LEXINGTON ST, EAST BOSTON, MA 02128       3.00       NaN        NaN
# 1  197 LEXINGTON ST, EAST BOSTON, MA 02128       3.00       NaN        NaN
# 2  199 LEXINGTON ST, EAST BOSTON, MA 02128       3.00       NaN        NaN
# 3          PO BOX 557 #, EVERETT, MA 02149       3.00       NaN        NaN
# 4  203 Lexington ST, EAST BOSTON, MA 02128       3.00       NaN        NaN
#
#    COM_UNITS  RC_UNITS  LAND_SF  GROSS_AREA  LIVING_AREA  LAND_VALUE  \
# 0        NaN       NaN  1150.00     3353.00      2202.00      195700
# 1        NaN       NaN  1150.00     3299.00      2307.00      196500
# 2        NaN       NaN  1150.00     3392.00      2268.00      197100
# 3        NaN       NaN  1150.00     3108.00      2028.00      197700
# 4        NaN       NaN  2010.00     3700.00      2546.00      225700
#
#    BLDG_VALUE  TOTAL_VALUE  GROSS_TAX  YR_BUILT  YR_REMODEL STRUCTURE_CLASS  \
# 0      588500       784200    8422.31   1900.00         NaN             NaN
# 1      615300       811800    8718.73   1920.00     2000.00             NaN
# 2      599200       796300    8552.26   1905.00     1985.00             NaN
# 3      530200       727900    7817.65   1900.00     1991.00             NaN
# 4      569100       794800    8536.15   1900.00     1978.00             NaN
#
#   ROOF_STRUCTURE       ROOF_COVER    INT_WALL   EXT_FNISHED     INT_COND  \
# 0       F - Flat  C - Composition  N - Normal  A - Asbestos  A - Average
# 1       F - Flat  C - Composition  N - Normal     M - Vinyl  A - Average
# 2       F - Flat  C - Composition  N - Normal     M - Vinyl  A - Average
# 3    M - Mansard  C - Composition  N - Normal     M - Vinyl  A - Average
# 4    M - Mansard  C - Composition  N - Normal     M - Vinyl  A - Average
#
#       EXT_COND OVERALL_COND  BED_RMS  FULL_BTH  HLF_BTH  KITCHENS  TT_RMS  \
# 0     F - Fair  A - Average     6.00      3.00     0.00      3.00   12.00
# 1  A - Average  A - Average     3.00      3.00     0.00      3.00    9.00
# 2     G - Good  A - Average     5.00      3.00     0.00      3.00   13.00
# 3  A - Average  A - Average     5.00      3.00     0.00      3.00   11.00
# 4  A - Average  A - Average     6.00      3.00     0.00      2.00   13.00
#
#   BDRM_COND     BTHRM_STYLE1     BTHRM_STYLE2     BTHRM_STYLE3  \
# 0       NaN  S - Semi-Modern  S - Semi-Modern  S - Semi-Modern
# 1       NaN       M - Modern       M - Modern       M - Modern
# 2       NaN       M - Modern       M - Modern       M - Modern
# 3       NaN  S - Semi-Modern  S - Semi-Modern  S - Semi-Modern
# 4       NaN  S - Semi-Modern  S - Semi-Modern  S - Semi-Modern
#
#                   KITCHEN_TYPE   KITCHEN_STYLE1   KITCHEN_STYLE2  \
# 0  3F - 3 Full Eat In Kitchens  S - Semi-Modern  S - Semi-Modern
# 1  3F - 3 Full Eat In Kitchens       M - Modern       M - Modern
# 2  3F - 3 Full Eat In Kitchens  S - Semi-Modern  S - Semi-Modern
# 3  3F - 3 Full Eat In Kitchens  S - Semi-Modern  S - Semi-Modern
# 4  2F - 2 Full Eat In Kitchens  S - Semi-Modern  S - Semi-Modern
#
#     KITCHEN_STYLE3           HEAT_TYPE HEAT_FUEL         AC_TYPE  FIREPLACES  \
# 0  S - Semi-Modern  W - Ht Water/Steam       NaN        N - None        0.00
# 1       M - Modern  F - Forced Hot Air       NaN  C - Central AC        0.00
# 2  S - Semi-Modern      S - Space Heat       NaN        N - None        0.00
# 3  S - Semi-Modern  W - Ht Water/Steam       NaN        N - None        0.00
# 4              NaN  W - Ht Water/Steam       NaN        N - None        0.00
#
#   ORIENTATION  NUM_PARKING    PROP_VIEW CORNER_UNIT
# 0         NaN         3.00  A - Average         NaN
# 1         NaN         0.00  A - Average         NaN
# 2         NaN         0.00  A - Average         NaN
# 3         NaN         0.00  A - Average         NaN
# 4         NaN         0.00  A - Average         NaN

# %%
assesment_data.shape
# Out:
# (180627, 60)

# %%
assesment_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180627 entries, 0 to 180626
# Data columns (total 60 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   PID                 180627 non-null  int64
#  1   CM_ID               91160 non-null   float64
#  2   GIS_ID              180627 non-null  int64
#  3   ST_NUM              171096 non-null  float64
#  4   ST_NAME             180627 non-null  object
#  5   UNIT_NUM            80672 non-null   object
#  6   CITY                180622 non-null  object
#  7   ZIP_CODE            180624 non-null  float64
#  8   BLDG_SEQ            180626 non-null  float64
#  9   NUM_BLDGS           180627 non-null  int64
#  10  LUC                 180627 non-null  int64
#  11  LU                  180627 non-null  object
#  12  LU_DESC             180627 non-null  object
#  13  BLDG_TYPE           178101 non-null  object
#  14  OWN_OCC             180627 non-null  object
#  15  OWNER               180627 non-null  object
#  16  OWNER MAIL ADDRESS  180626 non-null  object
#  17  RES_FLOOR           147122 non-null  float64
#  18  CD_FLOOR            70556 non-null   float64
#  19  RES_UNITS           10330 non-null   float64
#  20  COM_UNITS           623 non-null     float64
#  21  RC_UNITS            37 non-null      float64
#  22  LAND_SF             173082 non-null  float64
#  23  GROSS_AREA          145994 non-null  float64
#  24  LIVING_AREA         145704 non-null  float64
#  25  LAND_VALUE          180627 non-null  int64
#  26  BLDG_VALUE          180627 non-null  int64
#  27  TOTAL_VALUE         180627 non-null  int64
#  28  GROSS_TAX           180627 non-null  float64
#  29  YR_BUILT            157697 non-null  float64
#  30  YR_REMODEL          85400 non-null   float64
#  31  STRUCTURE_CLASS     17060 non-null   object
#  32  ROOF_STRUCTURE      144207 non-null  object
#  33  ROOF_COVER          144209 non-null  object
#  34  INT_WALL            132361 non-null  object
#  35  EXT_FNISHED         157606 non-null  object
#  36  INT_COND            132362 non-null  object
#  37  EXT_COND            144244 non-null  object
#  38  OVERALL_COND        171168 non-null  object
#  39  BED_RMS             132340 non-null  float64
#  40  FULL_BTH            169511 non-null  float64
#  41  HLF_BTH             169663 non-null  float64
#  42  KITCHENS            169513 non-null  float64
#  43  TT_RMS              132273 non-null  float64
#  44  BDRM_COND           70470 non-null   object
#  45  BTHRM_STYLE1        132529 non-null  object
#  46  BTHRM_STYLE2        85007 non-null   object
#  47  BTHRM_STYLE3        36266 non-null   object
#  48  KITCHEN_TYPE        132511 non-null  object
#  49  KITCHEN_STYLE1      132525 non-null  object
#  50  KITCHEN_STYLE2      31815 non-null   object
#  51  KITCHEN_STYLE3      14073 non-null   object
#  52  HEAT_TYPE           132782 non-null  object
#  53  HEAT_FUEL           70812 non-null   object
#  54  AC_TYPE             132768 non-null  object
#  55  FIREPLACES          169666 non-null  float64
#  56  ORIENTATION         70779 non-null   object
#  57  NUM_PARKING         132427 non-null  float64
#  58  PROP_VIEW           133865 non-null  object
#  59  CORNER_UNIT         70791 non-null   object
# dtypes: float64(22), int64(7), object(31)
# memory usage: 82.7+ MB

# %% [markdown]
# ## Data Preprocessing

# %%
#Check for Duplicates
duplicates_in_data = assesment_data[assesment_data.duplicated(['PID'])]
print(f"The duplicates found in the PID column:{duplicates_in_data.count()}")
# Out:
# The duplicates found in the PID column:PID                   179
# CM_ID                   2
# GIS_ID                179
# ST_NUM                176
# ST_NAME               179
# UNIT_NUM                1
# CITY                  178
# ZIP_CODE              179
# BLDG_SEQ              179
# NUM_BLDGS             179
# LUC                   179
# LU                    179
# LU_DESC               179
# BLDG_TYPE             179
# OWN_OCC               179
# OWNER                 179
# OWNER MAIL ADDRESS    179
# RES_FLOOR             178
# CD_FLOOR                1
# RES_UNITS               1
# COM_UNITS               0
# RC_UNITS                0
# LAND_SF               179
# GROSS_AREA            178
# LIVING_AREA           178
# LAND_VALUE            179
# BLDG_VALUE            179
# TOTAL_VALUE           179
# GROSS_TAX             179
# YR_BUILT              179
# YR_REMODEL             68
# STRUCTURE_CLASS         4
# ROOF_STRUCTURE        179
# ROOF_COVER            179
# INT_WALL              177
# EXT_FNISHED           179
# INT_COND              178
# EXT_COND              179
# OVERALL_COND          179
# BED_RMS               178
# FULL_BTH              178
# HLF_BTH               178
# KITCHENS              178
# TT_RMS                178
# BDRM_COND               1
# BTHRM_STYLE1          178
# BTHRM_STYLE2          137
# BTHRM_STYLE3           71
# KITCHEN_TYPE          178
# KITCHEN_STYLE1        178
# KITCHEN_STYLE2         98
# KITCHEN_STYLE3         43
# HEAT_TYPE             178
# HEAT_FUEL               1
# AC_TYPE               177
# FIREPLACES            177
# ORIENTATION             1
# NUM_PARKING           176
# PROP_VIEW             179
# CORNER_UNIT             1
# dtype: int64

# %%
#Drop the duplicates
# drop duplicates in 'PID' in the original DataFrame
assesment_data.drop_duplicates(subset='PID', keep='last', inplace=True)

# %%
#Check weather all duplicates have been removed
duplicates_in_data = assesment_data[assesment_data.duplicated(['PID'])]
print(f"The duplicates found in the PID column:{duplicates_in_data.count()}")
# Out:
# The duplicates found in the PID column:PID                   0
# CM_ID                 0
# GIS_ID                0
# ST_NUM                0
# ST_NAME               0
# UNIT_NUM              0
# CITY                  0
# ZIP_CODE              0
# BLDG_SEQ              0
# NUM_BLDGS             0
# LUC                   0
# LU                    0
# LU_DESC               0
# BLDG_TYPE             0
# OWN_OCC               0
# OWNER                 0
# OWNER MAIL ADDRESS    0
# RES_FLOOR             0
# CD_FLOOR              0
# RES_UNITS             0
# COM_UNITS             0
# RC_UNITS              0
# LAND_SF               0
# GROSS_AREA            0
# LIVING_AREA           0
# LAND_VALUE            0
# BLDG_VALUE            0
# TOTAL_VALUE           0
# GROSS_TAX             0
# YR_BUILT              0
# YR_REMODEL            0
# STRUCTURE_CLASS       0
# ROOF_STRUCTURE        0
# ROOF_COVER            0
# INT_WALL              0
# EXT_FNISHED           0
# INT_COND              0
# EXT_COND              0
# OVERALL_COND          0
# BED_RMS               0
# FULL_BTH              0
# HLF_BTH               0
# KITCHENS              0
# TT_RMS                0
# BDRM_COND             0
# BTHRM_STYLE1          0
# BTHRM_STYLE2          0
# BTHRM_STYLE3          0
# KITCHEN_TYPE          0
# KITCHEN_STYLE1        0
# KITCHEN_STYLE2        0
# KITCHEN_STYLE3        0
# HEAT_TYPE             0
# HEAT_FUEL             0
# AC_TYPE               0
# FIREPLACES            0
# ORIENTATION           0
# NUM_PARKING           0
# PROP_VIEW             0
# CORNER_UNIT           0
# dtype: int64

# %%
# Count total missing values at each column in DataFrame
missing_values_count = assesment_data.isnull().sum()

# Calculate percentage of missing values at each column in DataFrame
missing_values_percentage = (assesment_data.isnull().sum() / len(assesment_data)) * 100

# Create a new DataFrame with the column name, missing value count and missing value percentage
missing_data_df = pd.DataFrame({
    'Missing Value Count': missing_values_count,
    'Missing Value Percentage': missing_values_percentage
})

# Format the 'Missing Value Percentage' column as a percentage with 2 decimal places
missing_data_df['Missing Value Percentage'] = missing_data_df['Missing Value Percentage'].apply(lambda x: f'{x:.2f}%')

print(missing_data_df)
# Out:
#                     Missing Value Count Missing Value Percentage
# PID                                   0                    0.00%
# CM_ID                             89290                   49.48%
# GIS_ID                                0                    0.00%
# ST_NUM                             9528                    5.28%
# ST_NAME                               0                    0.00%
# UNIT_NUM                          99777                   55.29%
# CITY                                  4                    0.00%
# ZIP_CODE                              3                    0.00%
# BLDG_SEQ                              1                    0.00%
# NUM_BLDGS                             0                    0.00%
# LUC                                   0                    0.00%
# LU                                    0                    0.00%
# LU_DESC                               0                    0.00%
# BLDG_TYPE                          2526                    1.40%
# OWN_OCC                               0                    0.00%
# OWNER                                 0                    0.00%
# OWNER MAIL ADDRESS                    1                    0.00%
# RES_FLOOR                         33504                   18.57%
# CD_FLOOR                         109893                   60.90%
# RES_UNITS                        170119                   94.28%
# COM_UNITS                        179825                   99.65%
# RC_UNITS                         180411                   99.98%
# LAND_SF                            7545                    4.18%
# GROSS_AREA                        34632                   19.19%
# LIVING_AREA                       34922                   19.35%
# LAND_VALUE                            0                    0.00%
# BLDG_VALUE                            0                    0.00%
# TOTAL_VALUE                           0                    0.00%
# GROSS_TAX                             0                    0.00%
# YR_BUILT                          22930                   12.71%
# YR_REMODEL                        95118                   52.71%
# STRUCTURE_CLASS                  163393                   90.55%
# ROOF_STRUCTURE                    36420                   20.18%
# ROOF_COVER                        36418                   20.18%
# INT_WALL                          48265                   26.75%
# EXT_FNISHED                       23021                   12.76%
# INT_COND                          48264                   26.75%
# EXT_COND                          36383                   20.16%
# OVERALL_COND                       9459                    5.24%
# BED_RMS                           48284                   26.76%
# FULL_BTH                          11115                    6.16%
# HLF_BTH                           10962                    6.07%
# KITCHENS                          11113                    6.16%
# TT_RMS                            48350                   26.79%
# BDRM_COND                        109978                   60.95%
# BTHRM_STYLE1                      48097                   26.65%
# BTHRM_STYLE2                      95578                   52.97%
# BTHRM_STYLE3                     144258                   79.94%
# KITCHEN_TYPE                      48114                   26.66%
# KITCHEN_STYLE1                    48101                   26.66%
# KITCHEN_STYLE2                   148733                   82.42%
# KITCHEN_STYLE3                   166417                   92.22%
# HEAT_TYPE                         47844                   26.51%
# HEAT_FUEL                        109637                   60.76%
# AC_TYPE                           47858                   26.52%
# FIREPLACES                        10959                    6.07%
# ORIENTATION                      109670                   60.78%
# NUM_PARKING                       48198                   26.71%
# PROP_VIEW                         46762                   25.91%
# CORNER_UNIT                      109658                   60.77%

# %% [markdown]
# ### Drop Unwanted Columns

# %%
unwanted_columns = ['PID',
                    'CM_ID',
                    'GIS_ID',
                    'ST_NUM',
                    'ST_NAME',
                    'UNIT_NUM',
                    'LUC',
                    'LU',
                    'LU_DESC',
                    'OWNER MAIL ADDRESS',
                    'RES_FLOOR',
                    'RES_UNITS',
                    'COM_UNITS',
                    'LAND_SF',
                    'LAND_VALUE',
                    'YR_REMODEL',
                    'STRUCTURE_CLASS',
                    'ROOF_STRUCTURE',
                    'ROOF_COVER',
                    'INT_WALL',
                    'INT_COND',
                    'BED_RMS',
                    'FULL_BTH',
                    'HLF_BTH',
                    'BDRM_COND',
                    'BTHRM_STYLE1',
                    'BTHRM_STYLE2',
                    'BTHRM_STYLE3',
                    'KITCHEN_STYLE1',
                    'KITCHEN_STYLE2',
                    'KITCHEN_STYLE3',
                    'HEAT_FUEL',
                    'FIREPLACES',
                    'NUM_PARKING',
                    'PROP_VIEW',
                    'CORNER_UNIT',
                    'ZIP_CODE',
                    'OVERALL_COND'
                   ]
